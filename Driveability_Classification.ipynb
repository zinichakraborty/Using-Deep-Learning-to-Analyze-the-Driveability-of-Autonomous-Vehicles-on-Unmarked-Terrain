# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
# from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision import datasets, models


import numpy as np
import matplotlib.pyplot as plt
import random
from PIL import Image
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
label_map = {"Driveable":"0","Non-Driveable":"1"}

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
data_path = "/content/gdrive/My\ Drive/data/"

# %%
# go to the folder:
# %cd /content/gdrive/My\ Drive/data/
# print out the content of the folder:
# %ls

# %cd Test_Driveable_Classification_Dataset
# %ls
# Out:
# /content/gdrive/My Drive/data
#  Driveable_Classification_Dataset/  'SRA Paper Methods: Dataset.gdoc'
#  Driveable_Dataset/                  TerrainAndDriveableModel.pt
#  Flowers/                            Test_Driveable_Classification_Dataset/
#  __MACOSX/                           Test.txt
#  MiniImageNet/                       Train.txt
#  MNIST/                              Updated_Terrain_Classification_Dataset/
# /content/gdrive/My Drive/data/Test_Driveable_Classification_Dataset
# Test/  Train/

# %%
batch_size = 16
num_workers = 0

train_transform = transforms.Compose([
      transforms.RandomResizedCrop(224),
      transforms.RandomHorizontalFlip(p=0.5),
      transforms.RandomRotation(10),
      transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
      transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# define datasets:
train_data = datasets.ImageFolder("./Train", transform=train_transform)
test_data = datasets.ImageFolder("./Test", transform=test_transform)

# define dataloaders:
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers, shuffle=False)

# %%
# define model
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(in_features = 512, out_features = 7)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=7, bias=True)
# )

# %%
"""Train (and validate):"""

# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum = 0.9)
# specify scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# number of epochs to train the model
n_epochs = 20

# lists to keep track of training progress:
train_loss_progress = []

model.train() # prep model for training

n_iterations = int(len(train_data)/batch_size)

test_accuracies = []

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0

    ###################
    # train the model #
    ###################
    for iter, (data, target) in enumerate(train_loader):  

        print("Epoch:", epoch, "Iteration:", iter, "out of:", n_iterations)

        # clear the gradients of all optimized variables
        optimizer.zero_grad()

        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(data)

        # calculate the loss
        loss = criterion(outputs, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        
        # perform a single optimization step (parameter update)
        optimizer.step()
        
        # update running training loss
        train_loss += loss.item()*data.size(0)
      
    # if you have a learning rate scheduler - perform a its step in here
    scheduler.step()
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_loss_progress.append(train_loss)

    print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

    # Run the test pass:
    correct = 0
    total = 0
    model.eval()  # prep model for validation

    with torch.no_grad():
        for data, target in test_loader:
          outputs = model(data)
          _, predicted = torch.max(outputs.data, 1)
          total += target.size(0)
          correct += (predicted == target).sum().item()

    test_accuracy = 100 * correct / total
    print('Accuracy of the network on the test set: %d %%' % (test_accuracy))

    test_accuracies.append(test_accuracy)

print('Best accuracy of the network on the test set: %d %%' % (max(test_accuracies)))
print('Average accuracy of the network on the test set: %d %%' % (sum(test_accuracies) / len(test_accuracies)))
# Out:
# Epoch: 0 Iteration: 0 out of: 20
# Epoch: 0 Iteration: 1 out of: 20
# Epoch: 0 Iteration: 2 out of: 20
# Epoch: 0 Iteration: 3 out of: 20
# Epoch: 0 Iteration: 4 out of: 20
# Epoch: 0 Iteration: 5 out of: 20
# Epoch: 0 Iteration: 6 out of: 20
# Epoch: 0 Iteration: 7 out of: 20
# Epoch: 0 Iteration: 8 out of: 20
# Epoch: 0 Iteration: 9 out of: 20
# Epoch: 0 Iteration: 10 out of: 20
# Epoch: 0 Iteration: 11 out of: 20
# Epoch: 0 Iteration: 12 out of: 20
# Epoch: 0 Iteration: 13 out of: 20
# Epoch: 0 Iteration: 14 out of: 20
# Epoch: 0 Iteration: 15 out of: 20
# Epoch: 0 Iteration: 16 out of: 20
# Epoch: 0 Iteration: 17 out of: 20
# Epoch: 0 Iteration: 18 out of: 20
# Epoch: 0 Iteration: 19 out of: 20
# Epoch: 0 Iteration: 20 out of: 20
# Epoch: 1 	Training Loss: 0.524806
# Accuracy of the network on the test set: 73 %
# Epoch: 1 Iteration: 0 out of: 20
# Epoch: 1 Iteration: 1 out of: 20
# Epoch: 1 Iteration: 2 out of: 20
# Epoch: 1 Iteration: 3 out of: 20
# Epoch: 1 Iteration: 4 out of: 20
# Epoch: 1 Iteration: 5 out of: 20
# Epoch: 1 Iteration: 6 out of: 20
# Epoch: 1 Iteration: 7 out of: 20
# Epoch: 1 Iteration: 8 out of: 20
# Epoch: 1 Iteration: 9 out of: 20
# Epoch: 1 Iteration: 10 out of: 20
# Epoch: 1 Iteration: 11 out of: 20
# Epoch: 1 Iteration: 12 out of: 20
# Epoch: 1 Iteration: 13 out of: 20
# Epoch: 1 Iteration: 14 out of: 20
# Epoch: 1 Iteration: 15 out of: 20
# Epoch: 1 Iteration: 16 out of: 20
# Epoch: 1 Iteration: 17 out of: 20
# Epoch: 1 Iteration: 18 out of: 20
# Epoch: 1 Iteration: 19 out of: 20
# Epoch: 1 Iteration: 20 out of: 20
# Epoch: 2 	Training Loss: 0.487299
# Accuracy of the network on the test set: 73 %
# Epoch: 2 Iteration: 0 out of: 20
# Epoch: 2 Iteration: 1 out of: 20
# Epoch: 2 Iteration: 2 out of: 20
# Epoch: 2 Iteration: 3 out of: 20
# Epoch: 2 Iteration: 4 out of: 20
# Epoch: 2 Iteration: 5 out of: 20
# Epoch: 2 Iteration: 6 out of: 20
# Epoch: 2 Iteration: 7 out of: 20
# Epoch: 2 Iteration: 8 out of: 20
# Epoch: 2 Iteration: 9 out of: 20
# Epoch: 2 Iteration: 10 out of: 20
# Epoch: 2 Iteration: 11 out of: 20
# Epoch: 2 Iteration: 12 out of: 20
# Epoch: 2 Iteration: 13 out of: 20
# Epoch: 2 Iteration: 14 out of: 20
# Epoch: 2 Iteration: 15 out of: 20
# Epoch: 2 Iteration: 16 out of: 20
# Epoch: 2 Iteration: 17 out of: 20
# Epoch: 2 Iteration: 18 out of: 20
# Epoch: 2 Iteration: 19 out of: 20
# Epoch: 2 Iteration: 20 out of: 20
# Epoch: 3 	Training Loss: 0.590158
# Accuracy of the network on the test set: 56 %
# Epoch: 3 Iteration: 0 out of: 20
# Epoch: 3 Iteration: 1 out of: 20
# Epoch: 3 Iteration: 2 out of: 20
# Epoch: 3 Iteration: 3 out of: 20
# Epoch: 3 Iteration: 4 out of: 20
# Epoch: 3 Iteration: 5 out of: 20
# Epoch: 3 Iteration: 6 out of: 20
# Epoch: 3 Iteration: 7 out of: 20
# Epoch: 3 Iteration: 8 out of: 20
# Epoch: 3 Iteration: 9 out of: 20
# Epoch: 3 Iteration: 10 out of: 20
# Epoch: 3 Iteration: 11 out of: 20
# Epoch: 3 Iteration: 12 out of: 20
# Epoch: 3 Iteration: 13 out of: 20
# Epoch: 3 Iteration: 14 out of: 20
# Epoch: 3 Iteration: 15 out of: 20
# Epoch: 3 Iteration: 16 out of: 20
# Epoch: 3 Iteration: 17 out of: 20
# Epoch: 3 Iteration: 18 out of: 20
# Epoch: 3 Iteration: 19 out of: 20
# Epoch: 3 Iteration: 20 out of: 20
# Epoch: 4 	Training Loss: 0.600232
# Accuracy of the network on the test set: 52 %
# Epoch: 4 Iteration: 0 out of: 20
# Epoch: 4 Iteration: 1 out of: 20
# Epoch: 4 Iteration: 2 out of: 20
# Epoch: 4 Iteration: 3 out of: 20
# Epoch: 4 Iteration: 4 out of: 20
# Epoch: 4 Iteration: 5 out of: 20
# Epoch: 4 Iteration: 6 out of: 20
# Epoch: 4 Iteration: 7 out of: 20
# Epoch: 4 Iteration: 8 out of: 20
# Epoch: 4 Iteration: 9 out of: 20
# Epoch: 4 Iteration: 10 out of: 20
# Epoch: 4 Iteration: 11 out of: 20
# Epoch: 4 Iteration: 12 out of: 20
# Epoch: 4 Iteration: 13 out of: 20
# Epoch: 4 Iteration: 14 out of: 20
# Epoch: 4 Iteration: 15 out of: 20
# Epoch: 4 Iteration: 16 out of: 20
# Epoch: 4 Iteration: 17 out of: 20
# Epoch: 4 Iteration: 18 out of: 20
# Epoch: 4 Iteration: 19 out of: 20
# Epoch: 4 Iteration: 20 out of: 20
# Epoch: 5 	Training Loss: 0.519884
# Accuracy of the network on the test set: 68 %
# Epoch: 5 Iteration: 0 out of: 20
# Epoch: 5 Iteration: 1 out of: 20
# Epoch: 5 Iteration: 2 out of: 20
# Epoch: 5 Iteration: 3 out of: 20
# Epoch: 5 Iteration: 4 out of: 20
# Epoch: 5 Iteration: 5 out of: 20
# Epoch: 5 Iteration: 6 out of: 20
# Epoch: 5 Iteration: 7 out of: 20
# Epoch: 5 Iteration: 8 out of: 20
# Epoch: 5 Iteration: 9 out of: 20
# Epoch: 5 Iteration: 10 out of: 20
# Epoch: 5 Iteration: 11 out of: 20
# Epoch: 5 Iteration: 12 out of: 20
# Epoch: 5 Iteration: 13 out of: 20
# Epoch: 5 Iteration: 14 out of: 20
# Epoch: 5 Iteration: 15 out of: 20
# Epoch: 5 Iteration: 16 out of: 20
# Epoch: 5 Iteration: 17 out of: 20
# Epoch: 5 Iteration: 18 out of: 20
# Epoch: 5 Iteration: 19 out of: 20
# Epoch: 5 Iteration: 20 out of: 20
# Epoch: 6 	Training Loss: 0.514653
# Accuracy of the network on the test set: 55 %
# Epoch: 6 Iteration: 0 out of: 20
# Epoch: 6 Iteration: 1 out of: 20
# Epoch: 6 Iteration: 2 out of: 20
# Epoch: 6 Iteration: 3 out of: 20
# Epoch: 6 Iteration: 4 out of: 20
# Epoch: 6 Iteration: 5 out of: 20
# Epoch: 6 Iteration: 6 out of: 20
# Epoch: 6 Iteration: 7 out of: 20
# Epoch: 6 Iteration: 8 out of: 20
# Epoch: 6 Iteration: 9 out of: 20
# Epoch: 6 Iteration: 10 out of: 20
# Epoch: 6 Iteration: 11 out of: 20
# Epoch: 6 Iteration: 12 out of: 20
# Epoch: 6 Iteration: 13 out of: 20
# Epoch: 6 Iteration: 14 out of: 20
# Epoch: 6 Iteration: 15 out of: 20
# Epoch: 6 Iteration: 16 out of: 20
# Epoch: 6 Iteration: 17 out of: 20
# Epoch: 6 Iteration: 18 out of: 20
# Epoch: 6 Iteration: 19 out of: 20
# Epoch: 6 Iteration: 20 out of: 20
# Epoch: 7 	Training Loss: 0.516171
# Accuracy of the network on the test set: 55 %
# Epoch: 7 Iteration: 0 out of: 20
# Epoch: 7 Iteration: 1 out of: 20
# Epoch: 7 Iteration: 2 out of: 20
# Epoch: 7 Iteration: 3 out of: 20
# Epoch: 7 Iteration: 4 out of: 20
# Epoch: 7 Iteration: 5 out of: 20
# Epoch: 7 Iteration: 6 out of: 20
# Epoch: 7 Iteration: 7 out of: 20
# Epoch: 7 Iteration: 8 out of: 20
# Epoch: 7 Iteration: 9 out of: 20
# Epoch: 7 Iteration: 10 out of: 20
# Epoch: 7 Iteration: 11 out of: 20
# Epoch: 7 Iteration: 12 out of: 20
# Epoch: 7 Iteration: 13 out of: 20
# Epoch: 7 Iteration: 14 out of: 20
# Epoch: 7 Iteration: 15 out of: 20
# Epoch: 7 Iteration: 16 out of: 20
# Epoch: 7 Iteration: 17 out of: 20
# Epoch: 7 Iteration: 18 out of: 20
# Epoch: 7 Iteration: 19 out of: 20
# Epoch: 7 Iteration: 20 out of: 20
# Epoch: 8 	Training Loss: 0.564648
# Accuracy of the network on the test set: 75 %
# Epoch: 8 Iteration: 0 out of: 20
# Epoch: 8 Iteration: 1 out of: 20
# Epoch: 8 Iteration: 2 out of: 20
# Epoch: 8 Iteration: 3 out of: 20
# Epoch: 8 Iteration: 4 out of: 20
# Epoch: 8 Iteration: 5 out of: 20
# Epoch: 8 Iteration: 6 out of: 20
# Epoch: 8 Iteration: 7 out of: 20
# Epoch: 8 Iteration: 8 out of: 20
# Epoch: 8 Iteration: 9 out of: 20
# Epoch: 8 Iteration: 10 out of: 20
# Epoch: 8 Iteration: 11 out of: 20
# Epoch: 8 Iteration: 12 out of: 20
# Epoch: 8 Iteration: 13 out of: 20
# Epoch: 8 Iteration: 14 out of: 20
# Epoch: 8 Iteration: 15 out of: 20
# Epoch: 8 Iteration: 16 out of: 20
# Epoch: 8 Iteration: 17 out of: 20
# Epoch: 8 Iteration: 18 out of: 20
# Epoch: 8 Iteration: 19 out of: 20
# Epoch: 8 Iteration: 20 out of: 20
# Epoch: 9 	Training Loss: 0.448358
# Accuracy of the network on the test set: 62 %
# Epoch: 9 Iteration: 0 out of: 20
# Epoch: 9 Iteration: 1 out of: 20
# Epoch: 9 Iteration: 2 out of: 20
# Epoch: 9 Iteration: 3 out of: 20
# Epoch: 9 Iteration: 4 out of: 20
# Epoch: 9 Iteration: 5 out of: 20
# Epoch: 9 Iteration: 6 out of: 20
# Epoch: 9 Iteration: 7 out of: 20
# Epoch: 9 Iteration: 8 out of: 20
# Epoch: 9 Iteration: 9 out of: 20
# Epoch: 9 Iteration: 10 out of: 20
# Epoch: 9 Iteration: 11 out of: 20
# Epoch: 9 Iteration: 12 out of: 20
# Epoch: 9 Iteration: 13 out of: 20
# Epoch: 9 Iteration: 14 out of: 20
# Epoch: 9 Iteration: 15 out of: 20
# Epoch: 9 Iteration: 16 out of: 20
# Epoch: 9 Iteration: 17 out of: 20
# Epoch: 9 Iteration: 18 out of: 20
# Epoch: 9 Iteration: 19 out of: 20
# Epoch: 9 Iteration: 20 out of: 20
# Epoch: 10 	Training Loss: 0.479650
# Accuracy of the network on the test set: 62 %
# Epoch: 10 Iteration: 0 out of: 20
# Epoch: 10 Iteration: 1 out of: 20
# Epoch: 10 Iteration: 2 out of: 20
# Epoch: 10 Iteration: 3 out of: 20
# Epoch: 10 Iteration: 4 out of: 20
# Epoch: 10 Iteration: 5 out of: 20
# Epoch: 10 Iteration: 6 out of: 20
# Epoch: 10 Iteration: 7 out of: 20
# Epoch: 10 Iteration: 8 out of: 20
# Epoch: 10 Iteration: 9 out of: 20
# Epoch: 10 Iteration: 10 out of: 20
# Epoch: 10 Iteration: 11 out of: 20
# Epoch: 10 Iteration: 12 out of: 20
# Epoch: 10 Iteration: 13 out of: 20
# Epoch: 10 Iteration: 14 out of: 20
# Epoch: 10 Iteration: 15 out of: 20
# Epoch: 10 Iteration: 16 out of: 20
# Epoch: 10 Iteration: 17 out of: 20
# Epoch: 10 Iteration: 18 out of: 20
# Epoch: 10 Iteration: 19 out of: 20
# Epoch: 10 Iteration: 20 out of: 20
# Epoch: 11 	Training Loss: 0.447651
# Accuracy of the network on the test set: 76 %
# Epoch: 11 Iteration: 0 out of: 20
# Epoch: 11 Iteration: 1 out of: 20
# Epoch: 11 Iteration: 2 out of: 20
# Epoch: 11 Iteration: 3 out of: 20
# Epoch: 11 Iteration: 4 out of: 20
# Epoch: 11 Iteration: 5 out of: 20
# Epoch: 11 Iteration: 6 out of: 20
# Epoch: 11 Iteration: 7 out of: 20
# Epoch: 11 Iteration: 8 out of: 20
# Epoch: 11 Iteration: 9 out of: 20
# Epoch: 11 Iteration: 10 out of: 20
# Epoch: 11 Iteration: 11 out of: 20
# Epoch: 11 Iteration: 12 out of: 20
# Epoch: 11 Iteration: 13 out of: 20
# Epoch: 11 Iteration: 14 out of: 20
# Epoch: 11 Iteration: 15 out of: 20
# Epoch: 11 Iteration: 16 out of: 20
# Epoch: 11 Iteration: 17 out of: 20
# Epoch: 11 Iteration: 18 out of: 20
# Epoch: 11 Iteration: 19 out of: 20
# Epoch: 11 Iteration: 20 out of: 20
# Epoch: 12 	Training Loss: 0.404210
# Accuracy of the network on the test set: 75 %
# Epoch: 12 Iteration: 0 out of: 20
# Epoch: 12 Iteration: 1 out of: 20
# Epoch: 12 Iteration: 2 out of: 20
# Epoch: 12 Iteration: 3 out of: 20
# Epoch: 12 Iteration: 4 out of: 20
# Epoch: 12 Iteration: 5 out of: 20
# Epoch: 12 Iteration: 6 out of: 20
# Epoch: 12 Iteration: 7 out of: 20
# Epoch: 12 Iteration: 8 out of: 20
# Epoch: 12 Iteration: 9 out of: 20
# Epoch: 12 Iteration: 10 out of: 20
# Epoch: 12 Iteration: 11 out of: 20
# Epoch: 12 Iteration: 12 out of: 20
# Epoch: 12 Iteration: 13 out of: 20
# Epoch: 12 Iteration: 14 out of: 20
# Epoch: 12 Iteration: 15 out of: 20
# Epoch: 12 Iteration: 16 out of: 20
# Epoch: 12 Iteration: 17 out of: 20
# Epoch: 12 Iteration: 18 out of: 20
# Epoch: 12 Iteration: 19 out of: 20
# Epoch: 12 Iteration: 20 out of: 20
# Epoch: 13 	Training Loss: 0.391223
# Accuracy of the network on the test set: 73 %
# Epoch: 13 Iteration: 0 out of: 20
# Epoch: 13 Iteration: 1 out of: 20
# Epoch: 13 Iteration: 2 out of: 20
# Epoch: 13 Iteration: 3 out of: 20
# Epoch: 13 Iteration: 4 out of: 20
# Epoch: 13 Iteration: 5 out of: 20
# Epoch: 13 Iteration: 6 out of: 20
# Epoch: 13 Iteration: 7 out of: 20
# Epoch: 13 Iteration: 8 out of: 20
# Epoch: 13 Iteration: 9 out of: 20
# Epoch: 13 Iteration: 10 out of: 20
# Epoch: 13 Iteration: 11 out of: 20
# Epoch: 13 Iteration: 12 out of: 20
# Epoch: 13 Iteration: 13 out of: 20
# Epoch: 13 Iteration: 14 out of: 20
# Epoch: 13 Iteration: 15 out of: 20
# Epoch: 13 Iteration: 16 out of: 20
# Epoch: 13 Iteration: 17 out of: 20
# Epoch: 13 Iteration: 18 out of: 20
# Epoch: 13 Iteration: 19 out of: 20
# Epoch: 13 Iteration: 20 out of: 20
# Epoch: 14 	Training Loss: 0.376485
# Accuracy of the network on the test set: 75 %
# Epoch: 14 Iteration: 0 out of: 20
# Epoch: 14 Iteration: 1 out of: 20
# Epoch: 14 Iteration: 2 out of: 20
# Epoch: 14 Iteration: 3 out of: 20
# Epoch: 14 Iteration: 4 out of: 20
# Epoch: 14 Iteration: 5 out of: 20
# Epoch: 14 Iteration: 6 out of: 20
# Epoch: 14 Iteration: 7 out of: 20
# Epoch: 14 Iteration: 8 out of: 20
# Epoch: 14 Iteration: 9 out of: 20
# Epoch: 14 Iteration: 10 out of: 20
# Epoch: 14 Iteration: 11 out of: 20
# Epoch: 14 Iteration: 12 out of: 20
# Epoch: 14 Iteration: 13 out of: 20
# Epoch: 14 Iteration: 14 out of: 20
# Epoch: 14 Iteration: 15 out of: 20
# Epoch: 14 Iteration: 16 out of: 20
# Epoch: 14 Iteration: 17 out of: 20
# Epoch: 14 Iteration: 18 out of: 20
# Epoch: 14 Iteration: 19 out of: 20
# Epoch: 14 Iteration: 20 out of: 20
# Epoch: 15 	Training Loss: 0.368490
# Accuracy of the network on the test set: 75 %
# Epoch: 15 Iteration: 0 out of: 20
# Epoch: 15 Iteration: 1 out of: 20
# Epoch: 15 Iteration: 2 out of: 20
# Epoch: 15 Iteration: 3 out of: 20
# Epoch: 15 Iteration: 4 out of: 20
# Epoch: 15 Iteration: 5 out of: 20
# Epoch: 15 Iteration: 6 out of: 20
# Epoch: 15 Iteration: 7 out of: 20
# Epoch: 15 Iteration: 8 out of: 20
# Epoch: 15 Iteration: 9 out of: 20
# Epoch: 15 Iteration: 10 out of: 20
# Epoch: 15 Iteration: 11 out of: 20
# Epoch: 15 Iteration: 12 out of: 20
# Epoch: 15 Iteration: 13 out of: 20
# Epoch: 15 Iteration: 14 out of: 20
# Epoch: 15 Iteration: 15 out of: 20
# Epoch: 15 Iteration: 16 out of: 20
# Epoch: 15 Iteration: 17 out of: 20
# Epoch: 15 Iteration: 18 out of: 20
# Epoch: 15 Iteration: 19 out of: 20
# Epoch: 15 Iteration: 20 out of: 20
# Epoch: 16 	Training Loss: 0.382908
# Accuracy of the network on the test set: 76 %
# Epoch: 16 Iteration: 0 out of: 20
# Epoch: 16 Iteration: 1 out of: 20
# Epoch: 16 Iteration: 2 out of: 20
# Epoch: 16 Iteration: 3 out of: 20
# Epoch: 16 Iteration: 4 out of: 20
# Epoch: 16 Iteration: 5 out of: 20
# Epoch: 16 Iteration: 6 out of: 20
# Epoch: 16 Iteration: 7 out of: 20
# Epoch: 16 Iteration: 8 out of: 20
# Epoch: 16 Iteration: 9 out of: 20
# Epoch: 16 Iteration: 10 out of: 20
# Epoch: 16 Iteration: 11 out of: 20
# Epoch: 16 Iteration: 12 out of: 20
# Epoch: 16 Iteration: 13 out of: 20
# Epoch: 16 Iteration: 14 out of: 20
# Epoch: 16 Iteration: 15 out of: 20
# Epoch: 16 Iteration: 16 out of: 20
# Epoch: 16 Iteration: 17 out of: 20
# Epoch: 16 Iteration: 18 out of: 20
# Epoch: 16 Iteration: 19 out of: 20
# Epoch: 16 Iteration: 20 out of: 20
# Epoch: 17 	Training Loss: 0.389805
# Accuracy of the network on the test set: 76 %
# Epoch: 17 Iteration: 0 out of: 20
# Epoch: 17 Iteration: 1 out of: 20
# Epoch: 17 Iteration: 2 out of: 20
# Epoch: 17 Iteration: 3 out of: 20
# Epoch: 17 Iteration: 4 out of: 20
# Epoch: 17 Iteration: 5 out of: 20
# Epoch: 17 Iteration: 6 out of: 20
# Epoch: 17 Iteration: 7 out of: 20
# Epoch: 17 Iteration: 8 out of: 20
# Epoch: 17 Iteration: 9 out of: 20
# Epoch: 17 Iteration: 10 out of: 20
# Epoch: 17 Iteration: 11 out of: 20
# Epoch: 17 Iteration: 12 out of: 20
# Epoch: 17 Iteration: 13 out of: 20
# Epoch: 17 Iteration: 14 out of: 20
# Epoch: 17 Iteration: 15 out of: 20
# Epoch: 17 Iteration: 16 out of: 20
# Epoch: 17 Iteration: 17 out of: 20
# Epoch: 17 Iteration: 18 out of: 20
# Epoch: 17 Iteration: 19 out of: 20
# Epoch: 17 Iteration: 20 out of: 20
# Epoch: 18 	Training Loss: 0.361131
# Accuracy of the network on the test set: 74 %
# Epoch: 18 Iteration: 0 out of: 20
# Epoch: 18 Iteration: 1 out of: 20
# Epoch: 18 Iteration: 2 out of: 20
# Epoch: 18 Iteration: 3 out of: 20
# Epoch: 18 Iteration: 4 out of: 20
# Epoch: 18 Iteration: 5 out of: 20
# Epoch: 18 Iteration: 6 out of: 20
# Epoch: 18 Iteration: 7 out of: 20
# Epoch: 18 Iteration: 8 out of: 20
# Epoch: 18 Iteration: 9 out of: 20
# Epoch: 18 Iteration: 10 out of: 20
# Epoch: 18 Iteration: 11 out of: 20
# Epoch: 18 Iteration: 12 out of: 20
# Epoch: 18 Iteration: 13 out of: 20
# Epoch: 18 Iteration: 14 out of: 20
# Epoch: 18 Iteration: 15 out of: 20
# Epoch: 18 Iteration: 16 out of: 20
# Epoch: 18 Iteration: 17 out of: 20
# Epoch: 18 Iteration: 18 out of: 20
# Epoch: 18 Iteration: 19 out of: 20
# Epoch: 18 Iteration: 20 out of: 20
# Epoch: 19 	Training Loss: 0.341048
# Accuracy of the network on the test set: 74 %
# Epoch: 19 Iteration: 0 out of: 20
# Epoch: 19 Iteration: 1 out of: 20
# Epoch: 19 Iteration: 2 out of: 20
# Epoch: 19 Iteration: 3 out of: 20
# Epoch: 19 Iteration: 4 out of: 20
# Epoch: 19 Iteration: 5 out of: 20
# Epoch: 19 Iteration: 6 out of: 20
# Epoch: 19 Iteration: 7 out of: 20
# Epoch: 19 Iteration: 8 out of: 20
# Epoch: 19 Iteration: 9 out of: 20
# Epoch: 19 Iteration: 10 out of: 20
# Epoch: 19 Iteration: 11 out of: 20
# Epoch: 19 Iteration: 12 out of: 20
# Epoch: 19 Iteration: 13 out of: 20
# Epoch: 19 Iteration: 14 out of: 20
# Epoch: 19 Iteration: 15 out of: 20
# Epoch: 19 Iteration: 16 out of: 20
# Epoch: 19 Iteration: 17 out of: 20
# Epoch: 19 Iteration: 18 out of: 20
# Epoch: 19 Iteration: 19 out of: 20
# Epoch: 19 Iteration: 20 out of: 20
# Epoch: 20 	Training Loss: 0.338865
# Accuracy of the network on the test set: 74 %
# Best accuracy of the network on the test set: 76 %
# Average accuracy of the network on the test set: 69 %

# %%
n_epochs = 20
# Plot the confusion matrix
def plot_confusion_matrix(y_true, y_predicted):
  cm = metrics.confusion_matrix(y_true, y_predicted)
  labels = list(label_map.keys())
  df_cm = pd.DataFrame(cm, index = labels, columns = labels)
  fig = plt.figure()
  res = sns.heatmap(df_cm, annot=True, cmap='Blues')
  plt.title("Confusion Matrix")
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
 
  plt.show()
  plt.close()


# Print accuracy, precision, recall, f1
def printStats(y_true, y_pred):
  accuracy = accuracy_score(y_true, y_pred) * 100
  precision = precision_score(y_true, y_pred, average="macro") * 100
  recall = recall_score(y_true, y_pred, average="macro") * 100
  f1 = f1_score(y_true, y_pred, average="macro") * 100

  print("Accuracy:", accuracy)
  print("Precision:", precision)
  print("Recall:", recall)
  print("F1_score:", f1)

  return accuracy, precision, recall, f1


# Plot testing accuracy
def plot_graph(data, label):
  x_range_acc_t = np.arange(1, len(data) + 1)
  fig, axs = plt.subplots()
  axs.plot(x_range_acc_t, data, c='r', label=label)
  axs.legend()
  plt.ylabel('testing accuracy' if label == 'Test accuracy' else 'train loss')
  plt.xlabel('epoch')
  plt.xticks(range(0, n_epochs + 1, 5), range(0, n_epochs+1, 5))
  plt.grid(b=True, which='major', axis='y')
  plt.show()
  plt.close()


def save_model_info(model, model_name, loss, test_acc, acc, pre, recall, f1):
  PATH = f"./{model_name}_model.pt"
  torch.save({
              'model_state_dict': model.state_dict(),
              'train_loss_progress': loss,
              'test_accuracies': test_acc,
              'accuracy': acc,
              'precision': pre,
              'recall': recall,
              'f1': f1
            }, PATH)

# %%
# Plot confusion matrix
# checkpoint = torch.load("./Driveable_resnet18_model.pt")
# model.load_state_dict(checkpoint["model_state_dict"])
# model.eval()

target_vals = np.array([])
predicted_vals = np.array([])

with torch.no_grad():
        for data, target in test_loader:
            outputs = model(data)
            _, predicted = torch.max(outputs.data,1)
            predicted_vals = np.concatenate([predicted_vals, predicted.tolist()])
            target_vals = np.concatenate([target_vals, target.tolist()])

plot_confusion_matrix(target_vals, predicted_vals)

# %%
# Print accuracy, precision, recall, f1
accuracy, precision, recall, f1 = printStats(target_vals, predicted_vals)
# Out:
# Accuracy: 74.44444444444444
# Precision: 75.99789915966386
# Recall: 74.44444444444444
# F1_score: 74.05689936082216

# %%
# Plot train_loss_progress, test_accuracies_t, test_accuracies_d
plot_graph(train_loss_progress, "Train loss progress")
plot_graph(test_accuracies, "Test accuracy")

# %%
save_model_info(model, "Driveable_resnet18_updated", train_loss_progress, test_accuracies, accuracy, precision, recall, f1)
